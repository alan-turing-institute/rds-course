# %% [markdown]
# # Data Consistency
#
# - why (input error, etc.)
# - e.g. ints stored as str
# - Duplicated data
# - Simple checks to do
# - Pandas column dtypes
# - Numeric data: Check unique values, mean, min, max
# - Combine with domain knowledge (what are sensible ranges of values for each column)
# - Reason for strange values (e.g. missingness encoded as large negative value)
# - Input errors (decimal in wrong place, decimal instead of comma...)
# - How to fix/replace weird values

# %% [markdown]
# ## Having a First Look at the Data
#
# Here we will use the Iris dataset, a well-known example dataset for machine learning.

# %%
import pandas as pd

# %%
df = pd.read_csv("data/Iris.csv")

# %% [markdown]
# Display the first few ten rows of the data:
#
# Note: `display` is a Jupyter notebook function that displays tables with prettier formatting than Python's `print` function. The `display` function won't work outside of Jupyter notebooks.
#
# TODO: format note above with markdown styling

# %%
display(df.head(10))
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %% [markdown]
# We could also look at the last few rows of the data with `df.tail()`, or a random sample of rows with `df.sample()`.
#
# To check the number of rows and columns we can use:

# %%
print(df.shape)
# Out:
# (150, 6)

# %% [markdown]
# Our data has 150 rows and 6 columns. It might also be useful to look at the column names (especially for larger datasets with many columns where they may not all be displayed by `df.head()`):

# %%
print(df.columns)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# A useful command that summarises much of this information is `df.info()`:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# This gives us the number of rows (entries) and columns at the top, and then a table with the name, number of non-null values (i.e. the number of rows that have data) and data type of each column.
#
# Finally, it gives the amount of memory the data frame is using. Pandas can use a lot of memory, which may cause problems when analysing large datasets. The [Scaling to large datasets](https://pandas.pydata.org/pandas-docs/stable/user_guide/scale.html) page in the Pandas documentation gives pointers for what you can try in that case.

# %% [markdown]
# The pandas `describe()` function gives summary statistics for the numeric columns in our data (the mean, standard deviation, minimum and maximum value, and quartiles for each column):

# %%
display(df.describe())
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# Looking at these values gives us a better idea of what our data contains, but also allows us to perform some sanity checks. For example, do the minimum and maximum values in each column make sense?
#
# TODO: make it so there's a min/max value that looks wrong
#
# Note that the `Species` column does not appear above as it contains text. For both text and numeric columns it can be helpful to know the number of unique values in each column:

# %%
print(df.nunique())
# Out:
# Id               150
# SepalLengthCm     35
# SepalWidthCm      23
# PetalLengthCm     43
# PetalWidthCm      22
# Species            3
# dtype: int64

# %% [markdown]
# We see the `Id` column has as many different values as rows in our dataset, i.e. it is a unique identifier for each sample in the data. All the other columns have fewer than 150 unique values, and the `Species` column has three different values.
#
# The `value_counts()` function, applied to the `Species` column, shows the number of occurrences of the three different values in the dataset:

# %%
print(df["Species"].value_counts())
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# So we have 50 measurements each of "setosa", "versicolor", and "virginica" irises.
#
# TODO: Make it so a weird value turns up, e.g. UNKNOWN

# %% [markdown]
# ## Displaying Data Frames with Style 😎
#
# You can also get fancy with how you display data frames by highlighting and formatting cells differently using its `style` attribute. There are a few examples below, for more detailis see the [Table Visualization page in the Pandas documentation](https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html#Styler-Object-and-HTML).
#
# Change the precision with which numbers are displayed:

# %%
df_top10 = df.head(10)  # just style the first 10 rows for demo purposes here

# round values to nearest integer (0 decimal places)
display(df_top10.style.format(precision=0))
# Out:
# <style type="text/css">
# </style>
# <table id="T_4a579_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Id</th>
#       <th class="col_heading level0 col1" >SepalLengthCm</th>
#       <th class="col_heading level0 col2" >SepalWidthCm</th>
#       <th class="col_heading level0 col3" >PetalLengthCm</th>
#       <th class="col_heading level0 col4" >PetalWidthCm</th>
#       <th class="col_heading level0 col5" >Species</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a579_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4a579_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_4a579_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_4a579_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_4a579_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_4a579_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_4a579_row0_col5" class="data row0 col5" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_4a579_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4a579_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_4a579_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_4a579_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_4a579_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_4a579_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_4a579_row1_col5" class="data row1 col5" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_4a579_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4a579_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_4a579_row2_col1" class="data row2 col1" >5</td>
#       <td id="T_4a579_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_4a579_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_4a579_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_4a579_row2_col5" class="data row2 col5" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_4a579_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4a579_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_4a579_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_4a579_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_4a579_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_4a579_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_4a579_row3_col5" class="data row3 col5" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_4a579_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4a579_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_4a579_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_4a579_row4_col2" class="data row4 col2" >4</td>
#       <td id="T_4a579_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_4a579_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_4a579_row4_col5" class="data row4 col5" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_4a579_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4a579_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_4a579_row5_col1" class="data row5 col1" >5</td>
#       <td id="T_4a579_row5_col2" class="data row5 col2" >4</td>
#       <td id="T_4a579_row5_col3" class="data row5 col3" >2</td>
#       <td id="T_4a579_row5_col4" class="data row5 col4" >0</td>
#       <td id="T_4a579_row5_col5" class="data row5 col5" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_4a579_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4a579_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_4a579_row6_col1" class="data row6 col1" >5</td>
#       <td id="T_4a579_row6_col2" class="data row6 col2" >3</td>
#       <td id="T_4a579_row6_col3" class="data row6 col3" >1</td>
#       <td id="T_4a579_row6_col4" class="data row6 col4" >0</td>
#       <td id="T_4a579_row6_col5" class="data row6 col5" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_4a579_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4a579_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_4a579_row7_col1" class="data row7 col1" >5</td>
#       <td id="T_4a579_row7_col2" class="data row7 col2" >3</td>
#       <td id="T_4a579_row7_col3" class="data row7 col3" >2</td>
#       <td id="T_4a579_row7_col4" class="data row7 col4" >0</td>
#       <td id="T_4a579_row7_col5" class="data row7 col5" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_4a579_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4a579_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_4a579_row8_col1" class="data row8 col1" >4</td>
#       <td id="T_4a579_row8_col2" class="data row8 col2" >3</td>
#       <td id="T_4a579_row8_col3" class="data row8 col3" >1</td>
#       <td id="T_4a579_row8_col4" class="data row8 col4" >0</td>
#       <td id="T_4a579_row8_col5" class="data row8 col5" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_4a579_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4a579_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_4a579_row9_col1" class="data row9 col1" >5</td>
#       <td id="T_4a579_row9_col2" class="data row9 col2" >3</td>
#       <td id="T_4a579_row9_col3" class="data row9 col3" >2</td>
#       <td id="T_4a579_row9_col4" class="data row9 col4" >0</td>
#       <td id="T_4a579_row9_col5" class="data row9 col5" >Iris-setosa</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Apply a colour gradient to each column based on each cell's value:

# %%
display(df_top10.style.background_gradient())
# Out:
# <style type="text/css">
# #T_6ed8f_row0_col0, #T_6ed8f_row2_col3, #T_6ed8f_row8_col1, #T_6ed8f_row8_col2, #T_6ed8f_row9_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_6ed8f_row0_col1, #T_6ed8f_row4_col2 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_6ed8f_row0_col2, #T_6ed8f_row4_col1, #T_6ed8f_row7_col1 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_6ed8f_row0_col3, #T_6ed8f_row1_col3, #T_6ed8f_row4_col3, #T_6ed8f_row6_col3, #T_6ed8f_row8_col3 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_6ed8f_row0_col4, #T_6ed8f_row1_col4, #T_6ed8f_row2_col4, #T_6ed8f_row3_col0, #T_6ed8f_row3_col4, #T_6ed8f_row4_col4, #T_6ed8f_row7_col4, #T_6ed8f_row8_col4 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_6ed8f_row1_col0 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_6ed8f_row1_col1, #T_6ed8f_row3_col3, #T_6ed8f_row6_col2, #T_6ed8f_row7_col2, #T_6ed8f_row7_col3, #T_6ed8f_row9_col1, #T_6ed8f_row9_col3 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_6ed8f_row1_col2 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_6ed8f_row2_col0 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_6ed8f_row2_col1, #T_6ed8f_row2_col2 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_6ed8f_row3_col1, #T_6ed8f_row3_col2, #T_6ed8f_row6_col1, #T_6ed8f_row9_col2 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_6ed8f_row4_col0 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_6ed8f_row5_col0 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_6ed8f_row5_col1, #T_6ed8f_row5_col2, #T_6ed8f_row5_col3, #T_6ed8f_row5_col4, #T_6ed8f_row9_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_6ed8f_row6_col0, #T_6ed8f_row6_col4 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_6ed8f_row7_col0 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_6ed8f_row8_col0 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6ed8f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Id</th>
#       <th class="col_heading level0 col1" >SepalLengthCm</th>
#       <th class="col_heading level0 col2" >SepalWidthCm</th>
#       <th class="col_heading level0 col3" >PetalLengthCm</th>
#       <th class="col_heading level0 col4" >PetalWidthCm</th>
#       <th class="col_heading level0 col5" >Species</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6